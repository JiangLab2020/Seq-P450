# %%
import pandas as pd
import numpy as np

# %%
datas = ['Arabidopsis_thaliana','Glycine_max','Erigeron_breviscapus','Zea_mays','sheetall']

# %%
for data in datas:
    dfme = pd.read_csv('../out4cj/final/Arabidopsis_thaliana.csv',index_col=0)
    dfcj = pd.read_excel('../out4cj/Supplemental_Tables.xlsx',sheet_name='Table S11')
    dfcombine = pd.merge(dfme,dfcj,left_on=['enzyme','substrate','if_right'],right_on=['P450 enzyme','Substrate','Whether catalyzed'],how='left')
    break

# %%
dfcombine
# Out:
#                          enzyme substrate  Binding  if_right   cc  \
# 0                       CYP72A7       ABA      0.0     False  C14
# 1                      CYP708A2       ABA      0.0     False  C14
# 2                       CYP72A9       ABA      0.0     False  C14
# 3                      CYP71A16       ABA      0.0     False  C14
# 4     AF-A0A178WIC4-F1-model_v4       ABA      0.0     False  C14
# ...                         ...       ...      ...       ...  ...
# 9592                    CYP98A9       HMT      0.0     False   C1
# 9593                    CYP98A9       PHL      0.0     False   C1
# 9594                    CYP98A9       MAR      0.0     False  C11
# 9595                    CYP98A9       OBT      0.0     False  C15
# 9596                    CYP98A9       THA      0.0     False  C10
#
#       P450Mining_score_x  ESP_p450_score  Gnina_score  ESP_score  \
# 0               0.424105        0.074351        0.574   0.477649
# ...
