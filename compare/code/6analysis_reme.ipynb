# %%
import os

import pandas as pd

# %%
topk = 0.1

# %%
querynamelist = [
    "Arabidopsis_thaliana",
    "Erigeron_breviscapus",
    "Glycine_max",
    "Zea_mays",
    "sheetall",
]

# %%
def reme_processing():
    pass

# %%
def reme_download():
    pass
