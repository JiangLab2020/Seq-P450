# %%
import pickle

import numpy as np
import pandas as pd
import tomli
import xgboost as xgb
from sklearn.metrics import matthews_corrcoef, roc_auc_score

# %%
with open("src/config.toml", "rb") as f:
    config = tomli.load(f)

# %% [markdown]
# 1. 数据读取与处理(Data loading and processing)

# %%
# esp数据读取
# ESP data loading
df_test = pd.read_pickle(
    config["espData"]["encoded_path"] + "df_test_with_ESM1b_ts.pkl"
)
df_test = df_test.loc[df_test["ESM1b"] != ""]
df_test.reset_index(inplace=True, drop=True)

df_train = pd.read_pickle(
    config["espData"]["encoded_path"] + "df_train_with_ESM1b_ts.pkl"
)
df_train = df_train.loc[df_train["ESM1b"] != ""]
df_train.reset_index(inplace=True, drop=True)
# Out:
# /home/hanxd/miniconda3/envs/esp/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:82: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = libops.scalar_compare(x.ravel(), y, op)
# /home/hanxd/miniconda3/envs/esp/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:82: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
# 特征提取函数
# Feature extraction function


def create_input_and_output_data(df):
    X = ()
    y = ()
    ids = []
    for ind in df.index:
        emb = df["ESM1b"][ind]
        ecfp = np.array(list(df["ECFP"][ind])).astype(int)
        ids.append(ind)
        X = X + (np.concatenate([ecfp, emb]),)
        y = y + (df["Binding"][ind],)

    return (X, y, ids)


# 载入esp数据
# Load ESP data
train_X, train_y, _ = create_input_and_output_data(df=df_train)
test_X, test_y, _ = create_input_and_output_data(df=df_test)

feature_names = ["ECFP_" + str(i) for i in range(1024)]
feature_names = feature_names + ["ESM1b_" + str(i) for i in range(1280)]

# %%
# 读取Seq-P450数据
# Seq-P450 data loading
p450plant0 = pd.read_pickle(config["SeqP450Data"]["encoded_path"] + "p450plant0.pkl")
p450plant1 = pd.read_pickle(config["SeqP450Data"]["encoded_path"] + "p450plant1.pkl")
p450plant2 = pd.read_pickle(config["SeqP450Data"]["encoded_path"] + "p450plant2.pkl")
p450plant3 = pd.read_pickle(config["SeqP450Data"]["encoded_path"] + "p450plant3.pkl")
p450plant4 = pd.read_pickle(config["SeqP450Data"]["encoded_path"] + "p450plant4.pkl")

p450plants = [p450plant0, p450plant1, p450plant2, p450plant3, p450plant4]

train_Xloop = []
train_yloop = []
test_Xloop = []
test_yloop = []

train_idsloop = []
test_idsloop = []

train_set_loop = []
test_set_loop = []
num_folds = 5

# 进行五折交叉验证数据组合
# Perform five-fold cross-validation data splitting
for i in range(num_folds):
    # 取出训练集
    # Extract training set
    train_cache = pd.concat(p450plants[:i] + p450plants[i + 1 :])
    # 重置索引
    # Reset index
    train_cache.reset_index(inplace=True, drop=True)
    # 使用方法对数据处理
    # Process data using the method
    Mou_X_train, Mou_y_train, train_ids = create_input_and_output_data(df=train_cache)
    Mou_X_test, Mou_y_test, test_ids = create_input_and_output_data(df=p450plants[i])
    # 新旧数据拼接
    # Concatenate new and old data
    train_Xloop.append(np.concatenate([train_X, Mou_X_train]))
    train_yloop.append(np.concatenate([train_y, Mou_y_train]))
    test_Xloop.append(Mou_X_test)
    test_yloop.append(Mou_y_test)

    train_idsloop.append(train_ids)
    test_idsloop.append(test_ids)

    train_set_loop.append(pd.concat([df_train] + p450plants[:i] + p450plants[i + 1 :]))
    test_set_loop.append(p450plants[i])

# %% [markdown]
# 2. 模型训练与保存(Model training and saving)

# %%
# 使用esp原作者的方法及参数进行训练
# Train using the original ESP author's method and parameters

for i in range(num_folds):
    # 参数设置
    # Parameter settings
    param = {
        "learning_rate": 0.31553117247348733,
        "max_delta_step": 1.7726044219753656,
        "max_depth": 10,
        "min_child_weight": 1.3845040588450772,
        "num_rounds": 342.68325188584106,
        "reg_alpha": 0.531395259755843,
        "reg_lambda": 3.744980563764689,
        "weight": 0.26187490421514203,
    }

    num_round = param["num_rounds"]
    param["objective"] = "binary:logistic"
    param["eval_metric"] = ["error", "logloss"]

    weightss = np.array(
        [
            param["weight"] if binding == 0 else 1.0
            for binding in train_set_loop[i]["Binding"]
        ]
    )

    del param["num_rounds"]
    del param["weight"]
    # 数据集导入
    # Dataset import
    dtrain = xgb.DMatrix(
        np.array(train_Xloop[i]),
        weight=weightss,
        label=np.array(train_yloop[i]),
        feature_names=feature_names,
    )
    dtest = xgb.DMatrix(
        np.array(test_X), label=np.array(test_y), feature_names=feature_names
    )
    dtest_new = xgb.DMatrix(
        np.array(test_Xloop[i]),
        label=np.array(test_yloop[i]),
        feature_names=feature_names,
    )
    # 评估标准
    # Evaluation metrics
    evallist = [(dtest_new, "eval"), (dtrain, "train")]
    # 进行训练，并收集模型
    # Perform training and collect the model
    bst = xgb.train(param, dtrain, int(num_round), evallist, verbose_eval=10)
    # -------------------------------------------------------------------------------------------
    # 一系列数据评估
    # A series of data evaluations
    y_test_pred = np.round(bst.predict(dtest))
    acc_test = np.mean(y_test_pred == np.array(test_y))
    roc_auc = roc_auc_score(np.array(test_y), bst.predict(dtest))

    index_of_ones = np.where(np.array(test_y) == 1)[0]
    values_of_ones = bst.predict(dtest)[index_of_ones]
    acc_1 = np.mean(np.round(values_of_ones) == 1)

    index_of_zeros = np.where(np.array(test_y) == 0)[0]
    values_of_zeros = bst.predict(dtest)[index_of_zeros]
    acc_0 = np.mean(np.round(values_of_zeros) == 0)
    print("------------------------%d----------------------------------" % i)
    print(
        "Accuracy on test set: %s, ROC-AUC score for test set: %s" % (acc_test, roc_auc)
    )
    print("Accuracy on 1 set: %s, Accuracy on 0 set: %s" % (acc_1, acc_0))
    # -------------------------------------------------------------------------------------------
    y_test_new_pred = np.round(bst.predict(dtest_new))
    acc_test_new = np.mean(y_test_new_pred == np.array(test_yloop[i]))
    try:
        roc_auc_new = roc_auc_score(np.array(test_yloop[i]), bst.predict(dtest_new))
    except:
        roc_auc_new = 0
    try:
        mcc = matthews_corrcoef(np.array(test_yloop[i]), y_test_new_pred)
    except:
        mcc = 0
    index_of_ones = np.where(np.array(test_yloop[i]) == 1)[0]
    values_of_ones = bst.predict(dtest_new)[index_of_ones]
    acc_1_new = np.mean(np.round(values_of_ones) == 1)

    index_of_zeros = np.where(np.array(test_yloop[i]) == 0)[0]
    values_of_zeros = bst.predict(dtest_new)[index_of_zeros]
    acc_0_new = np.mean(np.round(values_of_zeros) == 0)

    print(
        "Accuracy on test set: %s, ROC-AUC score for test set: %s, MCC: %s"
        % (acc_test_new, roc_auc_new, mcc)
    )
    print("Accuracy on 1 set: %s, Accuracy on 0 set: %s" % (acc_1_new, acc_0_new))
    print(len(train_set_loop[i]))
    print(len(test_set_loop[i]))
    print("-------------------------------------------------------")
    print("\n\n")
    # -------------------------------------------------------------------------------------------
    # 模型保存
    # Model saving
    pickle.dump(
        bst,
        open(
            config["SeqP450Data"]["model_path"] + "slice" + str(i) + "model.dat", "wb"
        ),
    )

    np.save(
        config["SeqP450Data"]["encoded_path"] + "train" + str(i) + "_y_test_pred.npy",
        bst.predict(dtest_new),
    )
    np.save(
        config["SeqP450Data"]["encoded_path"] + "train" + str(i) + "_y_test.npy",
        np.array(test_yloop[i]),
    )
# Out:
# [0]	eval-error:0.55987	eval-logloss:0.70835	train-error:0.27139	train-logloss:0.62562
# [10]	eval-error:0.50485	eval-logloss:0.71420	train-error:0.14055	train-logloss:0.41934
# [20]	eval-error:0.37217	eval-logloss:0.63800	train-error:0.08870	train-logloss:0.34014
# [30]	eval-error:0.32039	eval-logloss:0.58696	train-error:0.06423	train-logloss:0.29236
# [40]	eval-error:0.27185	eval-logloss:0.55403	train-error:0.04689	train-logloss:0.25467
# [50]	eval-error:0.22977	eval-logloss:0.53077	train-error:0.03688	train-logloss:0.22287
# [60]	eval-error:0.23625	eval-logloss:0.50277	train-error:0.02961	train-logloss:0.19721
# [70]	eval-error:0.20712	eval-logloss:0.47980	train-error:0.02328	train-logloss:0.17343
# [80]	eval-error:0.22007	eval-logloss:0.47789	train-error:0.01934	train-logloss:0.15528
# [90]	eval-error:0.21359	eval-logloss:0.46974	train-error:0.01556	train-logloss:0.13749
# [100]	eval-error:0.22654	eval-logloss:0.46949	train-error:0.01266	train-logloss:0.12391
# [110]	eval-error:0.22007	eval-logloss:0.46699	train-error:0.01057	train-logloss:0.11352
# [120]	eval-error:0.22007	eval-logloss:0.46163	train-error:0.00880	train-logloss:0.10392
# [130]	eval-error:0.21359	eval-logloss:0.45699	train-error:0.00783	train-logloss:0.09619
# [140]	eval-error:0.21683	eval-logloss:0.45677	train-error:0.00659	train-logloss:0.08935
# [150]	eval-error:0.20065	eval-logloss:0.46124	train-error:0.00589	train-logloss:0.08310
# [160]	eval-error:0.20065	eval-logloss:0.45831	train-error:0.00532	train-logloss:0.07723
# [170]	eval-error:0.19417	eval-logloss:0.45552	train-error:0.00478	train-logloss:0.07175
# [180]	eval-error:0.19741	eval-logloss:0.45984	train-error:0.00423	train-logloss:0.06710
# [190]	eval-error:0.19417	eval-logloss:0.46020	train-error:0.00394	train-logloss:0.06276
# [200]	eval-error:0.19094	eval-logloss:0.46012	train-error:0.00345	train-logloss:0.05874
# [210]	eval-error:0.19741	eval-logloss:0.46192	train-error:0.00317	train-logloss:0.05555
# [220]	eval-error:0.19417	eval-logloss:0.46139	train-error:0.00292	train-logloss:0.05248
# [230]	eval-error:0.19094	eval-logloss:0.46039	train-error:0.00270	train-logloss:0.04936
# [240]	eval-error:0.18770	eval-logloss:0.45989	train-error:0.00246	train-logloss:0.04704
# [250]	eval-error:0.18770	eval-logloss:0.45981	train-error:0.00236	train-logloss:0.04466
# [260]	eval-error:0.19094	eval-logloss:0.45924	train-error:0.00215	train-logloss:0.04253
# [270]	eval-error:0.19417	eval-logloss:0.45774	train-error:0.00199	train-logloss:0.04067
# [280]	eval-error:0.19741	eval-logloss:0.45764	train-error:0.00186	train-logloss:0.03866
# [290]	eval-error:0.18447	eval-logloss:0.45601	train-error:0.00178	train-logloss:0.03712
# [300]	eval-error:0.18447	eval-logloss:0.45634	train-error:0.00168	train-logloss:0.03560
# [310]	eval-error:0.18770	eval-logloss:0.45596	train-error:0.00157	train-logloss:0.03417
# [320]	eval-error:0.18123	eval-logloss:0.45588	train-error:0.00148	train-logloss:0.03260
# [330]	eval-error:0.17799	eval-logloss:0.45470	train-error:0.00143	train-logloss:0.03143
# [340]	eval-error:0.18123	eval-logloss:0.45537	train-error:0.00138	train-logloss:0.03039
# [341]	eval-error:0.18123	eval-logloss:0.45517	train-error:0.00140	train-logloss:0.03032
# ------------------------0----------------------------------
# Accuracy on test set: 0.8988646549148491, ROC-AUC score for test set: 0.9369418294881157
# Accuracy on 1 set: 0.7357102433503112, Accuracy on 0 set: 0.9573777146336513
# Accuracy on test set: 0.8187702265372169, ROC-AUC score for test set: 0.8620275238005467, MCC: 0.5851919188596779
# Accuracy on 1 set: 0.6893203883495146, Accuracy on 0 set: 0.883495145631068
# 57219
# 309
# -------------------------------------------------------
#
#
#
# [0]	eval-error:0.56958	eval-logloss:0.70751	train-error:0.27326	train-logloss:0.62597
# [10]	eval-error:0.43042	eval-logloss:0.68327	train-error:0.13356	train-logloss:0.41572
# [20]	eval-error:0.36570	eval-logloss:0.62759	train-error:0.09088	train-logloss:0.35077
# [30]	eval-error:0.33333	eval-logloss:0.60599	train-error:0.06424	train-logloss:0.29803
# [40]	eval-error:0.31068	eval-logloss:0.56747	train-error:0.04605	train-logloss:0.25384
# [50]	eval-error:0.26861	eval-logloss:0.53457	train-error:0.03576	train-logloss:0.22304
# [60]	eval-error:0.23948	eval-logloss:0.51466	train-error:0.02897	train-logloss:0.19763
# [70]	eval-error:0.22654	eval-logloss:0.49768	train-error:0.02298	train-logloss:0.17333
# [80]	eval-error:0.23301	eval-logloss:0.48221	train-error:0.01895	train-logloss:0.15574
# [90]	eval-error:0.23948	eval-logloss:0.47516	train-error:0.01613	train-logloss:0.14077
# [100]	eval-error:0.22654	eval-logloss:0.46831	train-error:0.01350	train-logloss:0.12737
# [110]	eval-error:0.22007	eval-logloss:0.46361	train-error:0.01131	train-logloss:0.11575
# [120]	eval-error:0.22007	eval-logloss:0.45131	train-error:0.00951	train-logloss:0.10578
# [130]	eval-error:0.19741	eval-logloss:0.43940	train-error:0.00823	train-logloss:0.09663
# [140]	eval-error:0.18123	eval-logloss:0.43685	train-error:0.00673	train-logloss:0.08834
# [150]	eval-error:0.17799	eval-logloss:0.42905	train-error:0.00586	train-logloss:0.08207
# [160]	eval-error:0.16828	eval-logloss:0.42764	train-error:0.00511	train-logloss:0.07593
# [170]	eval-error:0.17152	eval-logloss:0.42458	train-error:0.00449	train-logloss:0.07094
# [180]	eval-error:0.16828	eval-logloss:0.42159	train-error:0.00406	train-logloss:0.06653
# [190]	eval-error:0.16181	eval-logloss:0.41578	train-error:0.00382	train-logloss:0.06230
# [200]	eval-error:0.16181	eval-logloss:0.41243	train-error:0.00336	train-logloss:0.05871
# [210]	eval-error:0.15858	eval-logloss:0.40894	train-error:0.00309	train-logloss:0.05552
# [220]	eval-error:0.15534	eval-logloss:0.40405	train-error:0.00285	train-logloss:0.05264
# [230]	eval-error:0.15210	eval-logloss:0.40145	train-error:0.00259	train-logloss:0.05002
# [240]	eval-error:0.14887	eval-logloss:0.39823	train-error:0.00245	train-logloss:0.04781
# [250]	eval-error:0.15210	eval-logloss:0.40126	train-error:0.00235	train-logloss:0.04522
# [260]	eval-error:0.14887	eval-logloss:0.39939	train-error:0.00216	train-logloss:0.04315
# [270]	eval-error:0.15210	eval-logloss:0.39657	train-error:0.00199	train-logloss:0.04118
# [280]	eval-error:0.15534	eval-logloss:0.39631	train-error:0.00186	train-logloss:0.03930
# [290]	eval-error:0.14887	eval-logloss:0.39277	train-error:0.00175	train-logloss:0.03756
# [300]	eval-error:0.15210	eval-logloss:0.39392	train-error:0.00165	train-logloss:0.03599
# [310]	eval-error:0.15534	eval-logloss:0.39404	train-error:0.00159	train-logloss:0.03450
# [320]	eval-error:0.15534	eval-logloss:0.39336	train-error:0.00153	train-logloss:0.03320
# [330]	eval-error:0.15210	eval-logloss:0.39331	train-error:0.00144	train-logloss:0.03190
# [340]	eval-error:0.15534	eval-logloss:0.39377	train-error:0.00144	train-logloss:0.03067
# [341]	eval-error:0.15534	eval-logloss:0.39388	train-error:0.00141	train-logloss:0.03054
# ------------------------1----------------------------------
# Accuracy on test set: 0.8969973110247983, ROC-AUC score for test set: 0.9370228080398264
# Accuracy on 1 set: 0.733446519524618, Accuracy on 0 set: 0.9556525268926325
# Accuracy on test set: 0.8446601941747572, ROC-AUC score for test set: 0.8986709397681214, MCC: 0.6582183780869638
# Accuracy on 1 set: 0.8058252427184466, Accuracy on 0 set: 0.8640776699029126
# 57219
# 309
# -------------------------------------------------------
#
#
#
# [0]	eval-error:0.59547	eval-logloss:0.71566	train-error:0.26955	train-logloss:0.62501
# [10]	eval-error:0.50162	eval-logloss:0.74331	train-error:0.13910	train-logloss:0.42092
# [20]	eval-error:0.45631	eval-logloss:0.68744	train-error:0.09166	train-logloss:0.34934
# [30]	eval-error:0.37217	eval-logloss:0.64529	train-error:0.06271	train-logloss:0.29651
# [40]	eval-error:0.36570	eval-logloss:0.62426	train-error:0.04742	train-logloss:0.25569
# [50]	eval-error:0.30421	eval-logloss:0.58894	train-error:0.03489	train-logloss:0.22123
# [60]	eval-error:0.27508	eval-logloss:0.56298	train-error:0.02716	train-logloss:0.19196
# [70]	eval-error:0.27508	eval-logloss:0.54417	train-error:0.02153	train-logloss:0.17075
# [80]	eval-error:0.24596	eval-logloss:0.52531	train-error:0.01829	train-logloss:0.15351
# [90]	eval-error:0.25566	eval-logloss:0.51417	train-error:0.01553	train-logloss:0.13941
# [100]	eval-error:0.26537	eval-logloss:0.50826	train-error:0.01216	train-logloss:0.12366
# [110]	eval-error:0.24919	eval-logloss:0.49577	train-error:0.01046	train-logloss:0.11236
# [120]	eval-error:0.24272	eval-logloss:0.48763	train-error:0.00907	train-logloss:0.10483
# [130]	eval-error:0.23301	eval-logloss:0.48208	train-error:0.00764	train-logloss:0.09552
# [140]	eval-error:0.22977	eval-logloss:0.47169	train-error:0.00679	train-logloss:0.08890
# [150]	eval-error:0.21036	eval-logloss:0.45996	train-error:0.00580	train-logloss:0.08212
# [160]	eval-error:0.21359	eval-logloss:0.45847	train-error:0.00492	train-logloss:0.07680
# [170]	eval-error:0.20712	eval-logloss:0.45224	train-error:0.00456	train-logloss:0.07144
# [180]	eval-error:0.20712	eval-logloss:0.44825	train-error:0.00399	train-logloss:0.06616
# [190]	eval-error:0.20712	eval-logloss:0.43946	train-error:0.00366	train-logloss:0.06151
# [200]	eval-error:0.19417	eval-logloss:0.43778	train-error:0.00325	train-logloss:0.05775
# [210]	eval-error:0.18123	eval-logloss:0.43273	train-error:0.00300	train-logloss:0.05424
# [220]	eval-error:0.18770	eval-logloss:0.43013	train-error:0.00278	train-logloss:0.05115
# [230]	eval-error:0.18770	eval-logloss:0.42473	train-error:0.00248	train-logloss:0.04835
# [240]	eval-error:0.18123	eval-logloss:0.42241	train-error:0.00237	train-logloss:0.04612
# [250]	eval-error:0.17476	eval-logloss:0.41990	train-error:0.00208	train-logloss:0.04351
# [260]	eval-error:0.17476	eval-logloss:0.42022	train-error:0.00203	train-logloss:0.04118
# [270]	eval-error:0.16828	eval-logloss:0.41888	train-error:0.00195	train-logloss:0.03931
# [280]	eval-error:0.17799	eval-logloss:0.41740	train-error:0.00185	train-logloss:0.03764
# [290]	eval-error:0.18447	eval-logloss:0.41688	train-error:0.00175	train-logloss:0.03602
# [300]	eval-error:0.18123	eval-logloss:0.41748	train-error:0.00168	train-logloss:0.03470
# [310]	eval-error:0.15858	eval-logloss:0.41390	train-error:0.00161	train-logloss:0.03339
# [320]	eval-error:0.16505	eval-logloss:0.41385	train-error:0.00153	train-logloss:0.03219
# [330]	eval-error:0.16828	eval-logloss:0.41096	train-error:0.00149	train-logloss:0.03093
# [340]	eval-error:0.17152	eval-logloss:0.41092	train-error:0.00147	train-logloss:0.02991
# [341]	eval-error:0.16828	eval-logloss:0.41035	train-error:0.00147	train-logloss:0.02982
# ------------------------2----------------------------------
# Accuracy on test set: 0.8964744547355841, ROC-AUC score for test set: 0.9376047049802039
# Accuracy on 1 set: 0.7263723825693266, Accuracy on 0 set: 0.957479196265476
# Accuracy on test set: 0.8317152103559871, ROC-AUC score for test set: 0.8870298802903196, MCC: 0.6343661712803605
# Accuracy on 1 set: 0.8058252427184466, Accuracy on 0 set: 0.8446601941747572
# 57219
# 309
# -------------------------------------------------------
#
#
#
# [0]	eval-error:0.57929	eval-logloss:0.70777	train-error:0.27095	train-logloss:0.62542
# [10]	eval-error:0.51456	eval-logloss:0.71557	train-error:0.13608	train-logloss:0.41816
# [20]	eval-error:0.42718	eval-logloss:0.66575	train-error:0.08783	train-logloss:0.34347
# [30]	eval-error:0.33981	eval-logloss:0.60207	train-error:0.06179	train-logloss:0.29402
# [40]	eval-error:0.32686	eval-logloss:0.57125	train-error:0.04832	train-logloss:0.25987
# [50]	eval-error:0.28803	eval-logloss:0.53384	train-error:0.03801	train-logloss:0.22900
# [60]	eval-error:0.28803	eval-logloss:0.51046	train-error:0.03039	train-logloss:0.20397
# [70]	eval-error:0.24596	eval-logloss:0.48862	train-error:0.02391	train-logloss:0.17958
# [80]	eval-error:0.22007	eval-logloss:0.45832	train-error:0.01892	train-logloss:0.15717
# [90]	eval-error:0.20712	eval-logloss:0.44510	train-error:0.01623	train-logloss:0.14381
# [100]	eval-error:0.21036	eval-logloss:0.43173	train-error:0.01363	train-logloss:0.12989
# [110]	eval-error:0.20712	eval-logloss:0.42763	train-error:0.01157	train-logloss:0.11802
# [120]	eval-error:0.18770	eval-logloss:0.41209	train-error:0.00946	train-logloss:0.10502
# [130]	eval-error:0.19417	eval-logloss:0.40550	train-error:0.00824	train-logloss:0.09729
# [140]	eval-error:0.18447	eval-logloss:0.40197	train-error:0.00709	train-logloss:0.08933
# [150]	eval-error:0.19094	eval-logloss:0.39596	train-error:0.00624	train-logloss:0.08226
# [160]	eval-error:0.17799	eval-logloss:0.39118	train-error:0.00562	train-logloss:0.07618
# [170]	eval-error:0.16828	eval-logloss:0.38627	train-error:0.00486	train-logloss:0.07076
# [180]	eval-error:0.16828	eval-logloss:0.38844	train-error:0.00436	train-logloss:0.06667
# [190]	eval-error:0.17476	eval-logloss:0.38770	train-error:0.00387	train-logloss:0.06244
# [200]	eval-error:0.17476	eval-logloss:0.38238	train-error:0.00352	train-logloss:0.05866
# [210]	eval-error:0.16828	eval-logloss:0.37632	train-error:0.00311	train-logloss:0.05506
# [220]	eval-error:0.17476	eval-logloss:0.37110	train-error:0.00290	train-logloss:0.05211
# [230]	eval-error:0.16505	eval-logloss:0.36841	train-error:0.00265	train-logloss:0.04949
# [240]	eval-error:0.17152	eval-logloss:0.36779	train-error:0.00249	train-logloss:0.04698
# [250]	eval-error:0.15858	eval-logloss:0.36214	train-error:0.00231	train-logloss:0.04467
# [260]	eval-error:0.16505	eval-logloss:0.36374	train-error:0.00215	train-logloss:0.04224
# [270]	eval-error:0.16828	eval-logloss:0.36108	train-error:0.00200	train-logloss:0.04051
# [280]	eval-error:0.15858	eval-logloss:0.35966	train-error:0.00191	train-logloss:0.03885
# [290]	eval-error:0.15858	eval-logloss:0.35962	train-error:0.00181	train-logloss:0.03725
# [300]	eval-error:0.16181	eval-logloss:0.36061	train-error:0.00168	train-logloss:0.03574
# [310]	eval-error:0.15858	eval-logloss:0.36078	train-error:0.00159	train-logloss:0.03446
# [320]	eval-error:0.15858	eval-logloss:0.35844	train-error:0.00153	train-logloss:0.03300
# [330]	eval-error:0.15534	eval-logloss:0.35847	train-error:0.00147	train-logloss:0.03189
# [340]	eval-error:0.15210	eval-logloss:0.35718	train-error:0.00139	train-logloss:0.03060
# [341]	eval-error:0.14563	eval-logloss:0.35743	train-error:0.00140	train-logloss:0.03047
# ------------------------3----------------------------------
# Accuracy on test set: 0.8952046608903496, ROC-AUC score for test set: 0.9372329789688938
# Accuracy on 1 set: 0.735144312393888, Accuracy on 0 set: 0.9526080779378933
# Accuracy on test set: 0.8543689320388349, ROC-AUC score for test set: 0.9156376661325292, MCC: 0.6807363084795599
# Accuracy on 1 set: 0.8252427184466019, Accuracy on 0 set: 0.8689320388349514
# 57219
# 309
# -------------------------------------------------------
#
#
#
# [0]	eval-error:0.56508	eval-logloss:0.70585	train-error:0.27166	train-logloss:0.62532
# [10]	eval-error:0.45397	eval-logloss:0.68513	train-error:0.13778	train-logloss:0.42385
# [20]	eval-error:0.38413	eval-logloss:0.64061	train-error:0.08865	train-logloss:0.34759
# [30]	eval-error:0.35556	eval-logloss:0.61564	train-error:0.05985	train-logloss:0.28929
# [40]	eval-error:0.31429	eval-logloss:0.58926	train-error:0.04457	train-logloss:0.25261
# [50]	eval-error:0.30476	eval-logloss:0.57003	train-error:0.03517	train-logloss:0.22065
# [60]	eval-error:0.30476	eval-logloss:0.56787	train-error:0.02783	train-logloss:0.19501
# [70]	eval-error:0.27936	eval-logloss:0.55241	train-error:0.02283	train-logloss:0.17616
# [80]	eval-error:0.28254	eval-logloss:0.54305	train-error:0.01874	train-logloss:0.15795
# [90]	eval-error:0.28571	eval-logloss:0.53699	train-error:0.01571	train-logloss:0.14291
# [100]	eval-error:0.27619	eval-logloss:0.52848	train-error:0.01296	train-logloss:0.12979
# [110]	eval-error:0.26984	eval-logloss:0.52587	train-error:0.01127	train-logloss:0.11880
# [120]	eval-error:0.24762	eval-logloss:0.50895	train-error:0.00978	train-logloss:0.10902
# [130]	eval-error:0.25397	eval-logloss:0.50808	train-error:0.00810	train-logloss:0.09878
# [140]	eval-error:0.24444	eval-logloss:0.51004	train-error:0.00708	train-logloss:0.09061
# [150]	eval-error:0.24444	eval-logloss:0.50872	train-error:0.00613	train-logloss:0.08375
# [160]	eval-error:0.23492	eval-logloss:0.50585	train-error:0.00527	train-logloss:0.07716
# [170]	eval-error:0.23810	eval-logloss:0.50397	train-error:0.00477	train-logloss:0.07221
# [180]	eval-error:0.23492	eval-logloss:0.50051	train-error:0.00417	train-logloss:0.06699
# [190]	eval-error:0.23810	eval-logloss:0.49934	train-error:0.00379	train-logloss:0.06292
# [200]	eval-error:0.23810	eval-logloss:0.50182	train-error:0.00346	train-logloss:0.05957
# [210]	eval-error:0.23492	eval-logloss:0.49596	train-error:0.00328	train-logloss:0.05636
# [220]	eval-error:0.23175	eval-logloss:0.50084	train-error:0.00305	train-logloss:0.05326
# [230]	eval-error:0.24127	eval-logloss:0.50193	train-error:0.00285	train-logloss:0.05049
# [240]	eval-error:0.23175	eval-logloss:0.49739	train-error:0.00258	train-logloss:0.04761
# [250]	eval-error:0.23175	eval-logloss:0.49586	train-error:0.00241	train-logloss:0.04538
# [260]	eval-error:0.23492	eval-logloss:0.49719	train-error:0.00227	train-logloss:0.04297
# [270]	eval-error:0.23810	eval-logloss:0.50034	train-error:0.00201	train-logloss:0.04091
# [280]	eval-error:0.23492	eval-logloss:0.49657	train-error:0.00189	train-logloss:0.03906
# [290]	eval-error:0.23175	eval-logloss:0.50142	train-error:0.00182	train-logloss:0.03732
# [300]	eval-error:0.23175	eval-logloss:0.50206	train-error:0.00172	train-logloss:0.03576
# [310]	eval-error:0.23175	eval-logloss:0.50209	train-error:0.00162	train-logloss:0.03437
# [320]	eval-error:0.22540	eval-logloss:0.50501	train-error:0.00153	train-logloss:0.03318
# [330]	eval-error:0.22857	eval-logloss:0.50706	train-error:0.00145	train-logloss:0.03188
# [340]	eval-error:0.22857	eval-logloss:0.50713	train-error:0.00143	train-logloss:0.03084
# [341]	eval-error:0.22857	eval-logloss:0.50776	train-error:0.00143	train-logloss:0.03071
# ------------------------4----------------------------------
# Accuracy on test set: 0.8976695548252166, ROC-AUC score for test set: 0.9364764038263687
# Accuracy on 1 set: 0.7365591397849462, Accuracy on 0 set: 0.9554495636289831
# Accuracy on test set: 0.7714285714285715, ROC-AUC score for test set: 0.8332199546485262, MCC: 0.49610769231360735
# Accuracy on 1 set: 0.6952380952380952, Accuracy on 0 set: 0.8095238095238095
# 57213
# 315
# -------------------------------------------------------
